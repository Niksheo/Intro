# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r'C:\Users\admin\Downloads\Toy-Sales.xlsx')

# %%
df.head()
# Out:
#    Month  Unit Sales  Price ($)  Adexp ('000$)  Promexp ('000$)
# 0      1       73959       8.75          50.04            61.13
# 1      2       71544       8.99          50.74            60.19
# 2      3       78587       7.50          50.14            59.16
# 3      4       80364       7.25          50.27            60.38
# 4      5       78771       7.40          51.25            59.71

# %%
df=df.drop('Month',axis=1)

# %%
df
# Out:
#     Unit Sales  Price ($)  Adexp ('000$)  Promexp ('000$)
# 0        73959       8.75          50.04            61.13
# 1        71544       8.99          50.74            60.19
# 2        78587       7.50          50.14            59.16
# 3        80364       7.25          50.27            60.38
# 4        78771       7.40          51.25            59.71
# 5        71986       8.50          50.65            59.88
# 6        74885       8.40          50.87            60.14
# 7        73345       7.90          50.15            60.08
# 8        76659       7.25          48.24            59.90
# 9        71880       8.70          50.19            59.68
# 10       73598       8.40          51.11            59.83
# 11       74893       8.10          51.49            59.77
# 12       69003       8.40          50.10            59.29
# 13       78542       7.40          49.24            60.40
# 14       72543       8.00          50.04            59.89
# ...

# %%
x=df[['Price ($)',"Adexp ('000$)","Promexp ('000$)"]]

# %%
x
# Out:
#     Price ($)  Adexp ('000$)  Promexp ('000$)
# 0        8.75          50.04            61.13
# 1        8.99          50.74            60.19
# 2        7.50          50.14            59.16
# 3        7.25          50.27            60.38
# 4        7.40          51.25            59.71
# 5        8.50          50.65            59.88
# 6        8.40          50.87            60.14
# 7        7.90          50.15            60.08
# 8        7.25          48.24            59.90
# 9        8.70          50.19            59.68
# 10       8.40          51.11            59.83
# 11       8.10          51.49            59.77
# 12       8.40          50.10            59.29
# 13       7.40          49.24            60.40
# 14       8.00          50.04            59.89
# 15       8.30          49.46            60.06
# 16       8.10          51.62            60.51
# 17       8.20          49.78            58.93
# 18       8.99          48.60            60.09
# ...

# %%
y=df['Unit Sales']

# %%
y
# Out:
# 0     73959
# 1     71544
# 2     78587
# 3     80364
# 4     78771
# 5     71986
# 6     74885
# 7     73345
# 8     76659
# 9     71880
# 10    73598
# 11    74893
# 12    69003
# 13    78542
# 14    72543
# 15    74247
# 16    76253
# 17    72582
# 18    69022
# 19    76200
# 20    69701
# 21    77005
# 22    70987
# 23    75643
# Name: Unit Sales, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=1)

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=LR.predict(x_test)

# %%
y_predict
# Out:
# array([78274.17427265, 69463.18684735, 79640.63429024, 74901.81885377,
#        69495.01490429, 71992.45716043])

# %%
y_test
# Out:
# 13    78542
# 18    69022
# 3     80364
# 14    72543
# 20    69701
# 17    72582
# Name: Unit Sales, dtype: int64

# %%
unit_sold=LR.predict([[8.5,51,60]])
print(unit_sold)
# Out:
# [73259.67046038]

# %%
#metrics

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print('r2 score',r2_score(y_test,y_predict))
# Out:
# r2 score 0.937712751179024

# %%
print('MAE',mean_absolute_error(y_test,y_predict))
# Out:
# MAE 764.4541789167561

# %%
print('RMSE',mean_squared_error(y_test,y_predict))
# Out:
# RMSE 1123941.9014682206

# %%
import numpy as ny

# %%
print('RMSE',ny.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# RMSE 1060.1612620107474
