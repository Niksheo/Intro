# %%
import pandas as pd

# %%
file=pd.read_excel(r'D:\Manipal University\MBA PDA\Class containt\5th_Nov.xlsx',sheet_name='Sheet1')

# %%
file
# Out:
#       Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0        23429 2016-03-18       Critical              28   165.4300
# 1          386 2018-01-23           High               4    16.0072
# 2        50754 2016-12-08  Not Specified               9    68.5100
# 3        42279 2016-06-29  Not Specified              44  1531.1700
# 4        53635 2019-07-18  Not Specified              33   111.1944
# ...        ...        ...            ...             ...        ...
# 8394     20389 2016-08-10           High              24   289.3200
# 8395     16193 2019-04-09  Not Specified              29  1460.3400
# 8396     57669 2017-08-07       Critical              41  1929.3400
# 8397     25313 2019-08-21       Critical              19   448.0100
# 8398     34374 2016-06-29            Low              42   368.6900
#
#         Ship Mode  Shipping Cost               Province Customer Segment  \
# 0     Regular Air            6.0                Ontario        Corporate
# ...

# %%
file['Sales'].head(10)
# Out:
# 0     165.4300
# 1      16.0072
# 2      68.5100
# 3    1531.1700
# 4     111.1944
# 5     692.5800
# 6     706.4900
# 7     531.9400
# 8      28.3600
# 9     103.9300
# Name: Sales, dtype: float64

# %%
file['Sales'].tail(10)
# Out:
# 8389    18516.19
# 8390      257.88
# 8391      208.69
# 8392      300.85
# 8393      306.80
# 8394      289.32
# 8395     1460.34
# 8396     1929.34
# 8397      448.01
# 8398      368.69
# Name: Sales, dtype: float64

# %%
file.isnull().sum().sum()
# Out:
# 0

# %%
file.describe()
# Out:
#            Order ID                     Order Date  Order Quantity  \
# count   8399.000000                           8399     8399.000000
# mean   29965.179783  2017-12-24 00:40:58.578402304       25.571735
# min        3.000000            2016-01-01 00:00:00        1.000000
# 25%    15011.500000            2016-12-19 00:00:00       13.000000
# 50%    29857.000000            2017-12-16 00:00:00       26.000000
# 75%    44596.000000            2018-12-31 12:00:00       38.000000
# max    59973.000000            2019-12-30 00:00:00       50.000000
# std    17260.883447                            NaN       14.481071
#
#               Sales  Shipping Cost                      Ship Date
# count   8399.000000    8399.000000                           8399
# mean    1900.189654      13.737457  2017-12-26 01:28:48.634361088
# min        2.400000       0.500000            2016-01-02 00:00:00
# 25%      153.218500       3.500000            2016-12-21 12:00:00
# ...

# %%
import seaborn as sns

# %%
sns.histplot(file['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
file['Sales'].var()
# Out:
# 14714926.972420657

# %%
sns.barplot(x='Order Priority',y='Sales',data=file)
# Out:
# <Axes: xlabel='Order Priority', ylabel='Sales'>

# %% [markdown]
# insights

# %%
sns.countplot(x='Order Priority',data=file)
# Out:
# <Axes: xlabel='Order Priority', ylabel='count'>

# %%
sns.boxplot(x='Order Quantity',data=file)#univerient numeric data
# Out:
# <Axes: xlabel='Order Quantity'>

# %%
sns.boxplot(x='Sales',data=file)
# Out:
# <Axes: xlabel='Sales'>

# %%
sns.scatterplot(x='Sales',y='Shipping Cost',data=file,hue='Ship Mode')
# Out:
# <Axes: xlabel='Sales', ylabel='Shipping Cost'>
