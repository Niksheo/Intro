# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df=df.dropna()

# %%
x=df[['cylinders','displacement','horsepower','weight','acceleration']]

# %%
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration
# 0            8         307.0       130.0    3504          12.0
# 1            8         350.0       165.0    3693          11.5
# 2            8         318.0       150.0    3436          11.0
# 3            8         304.0       150.0    3433          12.0
# 4            8         302.0       140.0    3449          10.5
# ..         ...           ...         ...     ...           ...
# 393          4         140.0        86.0    2790          15.6
# 394          4          97.0        52.0    2130          24.6
# 395          4         135.0        84.0    2295          11.6
# 396          4         120.0        79.0    2625          18.6
# 397          4         119.0        82.0    2720          19.4
#
# [392 rows x 5 columns]

# %%
y=df['mpg']

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=1)

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pridict=LR.predict(x_test)

# %%
y_pridict
# Out:
# array([26.25695032, 29.01243232, 28.11376826, 24.04838094, 30.22440036,
#        29.17660532, 29.32797217, 14.20524794, 27.93189879, 28.53885768,
#        21.11713615, 28.98122645, 17.04403418, 30.470626  , 26.62253402,
#        18.17260134, 27.10382358, 29.93486259,  9.3983822 , 23.30139469,
#        28.29144613, 19.40047262, 17.95790796, 13.26900962, 10.56353751,
#        15.12300049, 30.089405  , 19.94115067, 22.25858253, 27.02193864,
#        18.32830744, 25.2885596 , 12.35445294, 23.14187447, 20.7333759 ,
#        14.65133922, 19.58536255, 20.40728129, 30.26152641, 28.61483304,
#        11.39237374, 11.61485203, 23.51815791, 23.36452178, 23.8179261 ,
#        19.01505133,  9.71048591, 30.43698071, 21.76287182,  8.03609086,
#        16.80705857, 22.80364082, 25.56393374, 27.34137452, 31.06719751,
#        23.49681556, 24.43947672, 25.71741488, 25.85783963, 31.43763092,
#        23.1556396 , 27.06177164, 30.73745248, 20.48541999, 22.9703838 ,
# ...

# %%
y_test
# Out:
# 82     23.0
# 167    29.0
# 356    32.4
# 120    19.0
# 385    38.0
#        ...
# 27     11.0
# 90     12.0
# 307    26.8
# 74     13.0
# 276    21.6
# Name: mpg, Length: 98, dtype: float64

# %%
mpg=LR.predict([[4,140.0,86.0,2790,15.6]])
print(mpg)
# Out:
# [25.18232304]
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print('r2_score',r2_score(y_test,y_pridict))
# Out:
# r2_score 0.7273141417425495

# %%
print('MAE',mean_absolute_error(y_test,y_pridict))
# Out:
# MAE 3.1543561943036704

# %%
print('RMAE',mean_squared_error(y_test,y_pridict))
# Out:
# RMAE 19.44991707959557

# %%
import numpy as ny

# %%
print('mae',ny.sqrt(mean_squared_error(y_test,y_pridict)))
# Out:
# mae 20.332291340960992
